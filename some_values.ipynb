# %%
import numpy as np

data = np.loadtxt('some_values.txt')

# %%
import matplotlib.pyplot as plt

plt.plot(data)
plt.show()

# %%
med = np.median(data)
sq = np.std(data)

print("median is ",med, " mean is",np.mean(data), " sig is ",sq)
# Out:
# median is  1225.0  mean is 1226.66388889  sig is  37.1275702648
